# %%
#importing basic liabraries required to import the file and do some numerical calculations
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r'C:\Users\Downloads\loan.csv')
df.head()
# Out:
# C:\Users\Pratik\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3444: DtypeWarning: Columns (47) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  1077501    1296599       5000         5000           4975.0   36 months
# 1  1077430    1314167       2500         2500           2500.0   60 months
# 2  1077175    1313524       2400         2400           2400.0   36 months
# 3  1076863    1277178      10000        10000          10000.0   36 months
# 4  1075358    1311748       3000         3000           3000.0   60 months
#
#   int_rate  installment grade sub_grade  ... num_tl_90g_dpd_24m  \
# 0   10.65%       162.87     B        B2  ...                NaN
# 1   15.27%        59.83     C        C4  ...                NaN
# 2   15.96%        84.33     C        C5  ...                NaN
# ...

# %%
#basic information  of the dataframe
df.describe()
# Out:
#                  id     member_id     loan_amnt   funded_amnt  \
# count  3.971700e+04  3.971700e+04  39717.000000  39717.000000
# mean   6.831319e+05  8.504636e+05  11219.443815  10947.713196
# std    2.106941e+05  2.656783e+05   7456.670694   7187.238670
# min    5.473400e+04  7.069900e+04    500.000000    500.000000
# 25%    5.162210e+05  6.667800e+05   5500.000000   5400.000000
# 50%    6.656650e+05  8.508120e+05  10000.000000   9600.000000
# 75%    8.377550e+05  1.047339e+06  15000.000000  15000.000000
# max    1.077501e+06  1.314167e+06  35000.000000  35000.000000
#
#        funded_amnt_inv   installment    annual_inc           dti  \
# count     39717.000000  39717.000000  3.971700e+04  39717.000000
# mean      10397.448868    324.561922  6.896893e+04     13.315130
# std        7128.450439    208.874874  6.379377e+04      6.678594
# min           0.000000     15.690000  4.000000e+03      0.000000
# 25%        5000.000000    167.020000  4.040400e+04      8.170000
# ...

# %%
#checking the null values in all columns
df.isnull().sum()
# Out:
# id                                0
# member_id                         0
# loan_amnt                         0
# funded_amnt                       0
# funded_amnt_inv                   0
#                               ...
# tax_liens                        39
# tot_hi_cred_lim               39717
# total_bal_ex_mort             39717
# total_bc_limit                39717
# total_il_high_credit_limit    39717
# Length: 111, dtype: int64

# %%
col2=df['emp_title']
col2.unique()
# Out:
# array([nan, 'Ryder', 'AIR RESOURCES BOARD', ..., 'FiSite Research',
#        'Squarewave Solutions, Ltd.', 'Evergreen Center'], dtype=object)

# %%
#relationship between the loan amount and the tenure this reflects there is no such relationship between both as we can see amount increased but not tenure
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
plt.scatter(df.index,df['installment'])
plt.show()

# %%
# loan purpose differentioation using pie chart, this conveys the debt consolidation is more 
loans_purpose = loan.groupby(['purpose'])['funded_amnt_inv'].sum().reset_index()
plt.figure(figsize=(7, 5))
plt.pie(loans_purpose["funded_amnt_inv"],labels=loans_purpose["purpose"],autopct='%1.1f%%')
plt.title('Aggregated Information of the purpose of the loans')
plt.axis('equal')
plt.legend(loan_status,title="Loan purpose",loc="center left",bbox_to_anchor=(1, 0, 0.5, 1))
plt.show()

# %%
# in the given dataset multiple columns are with null values so removing the null value
# how="all" this function is used to drop all values from a column
loan = loan.dropna(axis=1, how="all")
print("remaining columns info:")
print(loan.info(max_cols=200))
# Out:
# remaining columns info:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 38577 entries, 0 to 39716
# Data columns (total 57 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   id                          38577 non-null  int64
#  1   member_id                   38577 non-null  int64
#  2   loan_amnt                   38577 non-null  int64
#  3   funded_amnt                 38577 non-null  int64
#  4   funded_amnt_inv             38577 non-null  float64
#  5   term                        38577 non-null  object
#  6   int_rate                    38577 non-null  object
#  7   installment                 38577 non-null  float64
#  8   grade                       38577 non-null  object
#  9   sub_grade                   38577 non-null  object
#  10  emp_title                   36191 non-null  object
#  11  emp_length                  37544 non-null  object
# ...

# %%
# as we want to draw information of default loans we should remove the current loan status data as it doesnt infer any info for default and then we will
# treat fully paid as 1 and charged off as 0 so that we can fetch some information from this column

# %%
# delete the rows with loan_status as "Current"
loan = loan[loan["loan_status"].apply(lambda x:False if x == "Current" else True)]
loan["loan_status"].unique()
# Out:
# array(['Fully Paid', 'Charged Off'], dtype=object)

# %%
# now convert it into numerical info
loan['loan_status']=loan['loan_status'].apply(lambda x: 0 if x=='Fully Paid' else 1 )
loan["loan_status"].unique()
# Out:
# array([0, 1], dtype=int64)

# %%
# create bins for loan_amnt range
binnings = [0, 5000, 10000, 15000, 20000, 25000, 36000]
loan_amnt_bukcet = ['0-5000', '5000-10000', '10000-15000', '15000-20000', '20000-25000','25000+']
loan['loan_amnt_range'] = pd.cut(loan['loan_amnt'], binnings, labels=loan_amnt_bukcet)
loan['loan_amnt_range'].unique()
# Out:
# ['0-5000', '5000-10000', '10000-15000', '20000-25000', '25000+', '15000-20000']
# Categories (6, object): ['0-5000' < '5000-10000' < '10000-15000' < '15000-20000' < '20000-25000' < '25000+']

# %%
# check for amount of defaults in the data using countplot
plt.figure(figsize=(6,1))
sns.countplot(y="loan_status", data=loan)
plt.show()

# %%
def scatterplot(x, y):
    plt.figure(figsize=(7,3))
    sns.scatterplot(x=x, y=y, hue="loan_status", data=loan)
    plt.show()

# %%
scatterplot("annual_inc", "funded_amnt_inv")

# %%
def scatterplot1(x, y):
    plt.figure(figsize=(7,3))
    sns.scatterplot(x=x, y=y, hue="installment", data=loan)
    plt.show()

# %%
#it shows that loan is acquired by more applicants whose income is slighly low and they are going for long tenure
scatterplot1("annual_inc", "funded_amnt_inv")

# %%
#it shows that loan is acquired by more applicants whose income is slighly low and they are going for long tenure
def scatterplot11(x, y):
    plt.figure(figsize=(7,3))
    sns.scatterplot(x=x, y=y, hue="int_rate", data=loan)
    plt.show()
